# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import PoissonRegressor
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  tkl+int  err  succ  succ% crdy   fls  won% season  \
# 0  Crystal Palace  ...       38  0.0  13.0   76.5    2  11.0  58.3   2022
# 1  Leicester City  ...       16  0.0  11.0   64.7    1  15.0  57.6   2022
# 2     Bournemouth  ...       24  1.0  12.0   44.4    1  10.0  53.8   2022
# 3          Fulham  ...       22  1.0  13.0   44.8    2   6.0  33.3   2022
# 4     Aston Villa  ...       18  0.0  12.0   52.2    2  10.0  50.0   2022
#
#       team  Unnamed: 0
# 0  Arsenal         NaN
# 1  Arsenal         NaN
# 2  Arsenal         NaN
# 3  Arsenal         NaN
# 4  Arsenal         NaN
#
# [5 rows x 53 columns]

# %% [markdown]
# # Data Exploration

# %%
matches.shape
# Out:
# (4282, 53)

# %%
matches["team"].value_counts()
# Out:
# Arsenal                     215
# Manchester City             215
# Tottenham Hotspur           215
# Everton                     215
# Manchester United           214
# Liverpool                   214
# Southampton                 214
# Chelsea                     214
# Crystal Palace              214
# West Ham United             214
# Leicester City              214
# Newcastle United            213
# Brighton and Hove Albion    212
# Burnley                     190
# Wolverhampton Wanderers     177
# Watford                     152
# Aston Villa                 138
# Bournemouth                 138
# Fulham                      101
# Leeds United                100
# Norwich City                 76
# West Bromwich Albion         76
# Sheffield United             76
# Huddersfield Town            76
# Brentford                    61
# Cardiff City                 38
# Swansea City                 38
# Stoke City                   38
# Nottingham Forest            24
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     120
# Matchweek 15    120
# Matchweek 24    120
# Matchweek 12    120
# Matchweek 23    120
# Matchweek 2     120
# Matchweek 21    120
# Matchweek 20    120
# Matchweek 19    120
# Matchweek 18    120
# Matchweek 17    120
# Matchweek 16    120
# Matchweek 22    120
# Matchweek 14    120
# Matchweek 6     120
# Matchweek 13    120
# Matchweek 4     120
# Matchweek 5     120
# Matchweek 3     120
# Matchweek 9     120
# Matchweek 10    120
# Matchweek 11    120
# Matchweek 8     116
# Matchweek 25    116
# Matchweek 7     110
# Matchweek 30    100
# Matchweek 37    100
# Matchweek 33    100
# Matchweek 36    100
# Matchweek 35    100
# Matchweek 34    100
# Matchweek 26    100
# Matchweek 32    100
# Matchweek 31    100
# Matchweek 29    100
# Matchweek 28    100
# Matchweek 27    100
# Matchweek 38    100
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# gls               int64
# sh              float64
# sot             float64
# dist            float64
# sota            float64
# save%           float64
# cs              float64
# psxg            float64
# cmp             float64
# cmp.1           float64
# cmp.2           float64
# cmp.3           float64
# cmp%            float64
# cmp%.1          float64
# cmp%.2          float64
# cmp%.3          float64
# prgdist         float64
# ast               int64
# ppa             float64
# prgp            float64
# sca             float64
# gca             float64
# tklw            float64
# int             float64
# tkl+int           int64
# err             float64
# succ            float64
# succ%           float64
# crdy              int64
# fls             float64
# won%            float64
# season            int64
# team             object
# Unnamed: 0      float64
# dtype: object

# %%
matches.columns.values
# Out:
# array(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf',
#        'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'gls', 'sh',
#        'sot', 'dist', 'sota', 'save%', 'cs', 'psxg', 'cmp', 'cmp.1',
#        'cmp.2', 'cmp.3', 'cmp%', 'cmp%.1', 'cmp%.2', 'cmp%.3', 'prgdist',
#        'ast', 'ppa', 'prgp', 'sca', 'gca', 'tklw', 'int', 'tkl+int',
#        'err', 'succ', 'succ%', 'crdy', 'fls', 'won%', 'season', 'team',
#        'Unnamed: 0'], dtype=object)

# %% [markdown]
# # Data Preparation

# %%
#Creating date as a datetime variable
matches["date"] = pd.to_datetime(matches["date"])

#Creating venue codes as a categorical variable
matches["venue_code"] = matches["venue"].astype("category").cat.codes

#Creating opponent codes as a categorical variable
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

#Creating team codes as a categorical variable
matches["team_code"] = matches["team"].astype("category").cat.codes

#Keeping the hour as integer value
matches["hour"] = matches["time"].str.replace(":.+","", regex = True).astype("int")

#Creating day codes as a categorical variable
matches["day_code"] = matches["date"].dt.dayofweek

#Creating numerical variable for team's form
form_dict = {'W':1, 'D':0, 'L':-1}
matches["form"] = matches["result"].replace(form_dict)

#Creating a target variable
matches["target"] = (matches["result"] == "W").astype("int")
#matches["target"] = matches["result"].astype("category").cat.codes

#Creating a team to score variable
matches["tts"] = np.where(matches["gf"] > 0, 1, 0)
matches["tts"] = matches["tts"].astype("category")

#Creating a team to concede variable
matches["ttc"] = np.where(matches["ga"] > 0, 1, 0)
matches["ttc"] = matches["ttc"].astype("category")

#Creating a both team to score variable
matches["btts"] = np.where(((matches["ga"] > 0) & (matches["gf"] > 0)), 1, 0)
matches["btts"] = matches["btts"].astype("category")

#Creating a goal above 2.5 variable
matches["above_2.5"] = np.where((matches["ga"] + matches["gf"]) > 2, 1, 0)
matches["above_2.5"] = matches["above_2.5"].astype("category")

#Creating a goal above 3.5 variable
matches["above_3.5"] = np.where((matches["ga"] + matches["gf"]) > 3, 1, 0)
matches["above_3.5"] = matches["above_3.5"].astype("category")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 39 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 40 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 41 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 42 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
#      ga        opponent  ...  team_code  hour  day_code  form target tts ttc  \
# 0   0.0  Crystal Palace  ...          0    20         4     1      1   1   0
# 1   2.0  Leicester City  ...          0    15         5     1      1   1   1
# 2   0.0     Bournemouth  ...          0    17         5     1      1   1   0
# 3   1.0          Fulham  ...          0    17         5     1      1   1   1
# 4   1.0     Aston Villa  ...          0    19         2     1      1   1   1
# ..  ...             ...  ...        ...   ...       ...   ...    ...  ..  ..
# 38  0.0  Manchester Utd  ...         26    16         6     1      1   1   0
# 39  2.0       Liverpool  ...         26    12         5     0      0   1   1
# 40  0.0   Newcastle Utd  ...         26    15         5     1      1   1   0
# 41  0.0       Tottenham  ...         26    15         5     1      1   1   0
# 42  2.0  Crystal Palace  ...         26    15         6    -1      0   0   1
#
#    btts  above_2.5  above_3.5
# 0     0          0          0
# 1     1          1          1
# 2     0          1          0
# 3     1          1          0
# 4     1          1          0
# ..  ...        ...        ...
# 38    0          0          0
# 39    1          1          1
# 40    0          0          0
# 41    0          0          0
# 42    0          0          0
#
# [4282 rows x 65 columns]

# %%
matches.dtypes
# Out:
# date         datetime64[ns]
# time                 object
# comp                 object
# round                object
# day                  object
#                   ...
# tts                category
# ttc                category
# btts               category
# above_2.5          category
# above_3.5          category
# Length: 65, dtype: object

# %% [markdown]
# # Modelling Using General Match Data

# %% [markdown]
# ## Model training

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["season"] != 2022]
test = matches[matches["season"] == 2022]
predictors = ["venue_code", "opp_code", "team_code"]
rf.fit(train[predictors], train["target"])
preds = rf.predict(test[predictors])

# %% [markdown]
# ## Model Evaluation

# %%
acc = accuracy_score(test["target"], preds)
prec = precision_score(test["target"], preds)
avg = len(test[test["target"]==1]) / len(test)
print("Accuracy:", acc)
print("Precision:", prec)
print("Average:", avg)
# Out:
# Accuracy: 0.5975103734439834
# Precision: 0.4658385093167702
# Average: 0.3796680497925311

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           213  86
# 1           108  75

# %% [markdown]
# # Modelling Using Match Statistic Data

# %% [markdown]
# ## Data Engineering

# %%
rf = RandomForestClassifier(n_estimators=150, min_samples_split=10, random_state=1)

def rolling_averages(group, cols, new_cols, n):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(n, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
matches.columns.values
# Out:
# array(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf',
#        'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'gls', 'sh',
#        'sot', 'dist', 'sota', 'save%', 'cs', 'psxg', 'cmp', 'cmp.1',
#        'cmp.2', 'cmp.3', 'cmp%', 'cmp%.1', 'cmp%.2', 'cmp%.3', 'prgdist',
#        'ast', 'ppa', 'prgp', 'sca', 'gca', 'tklw', 'int', 'tkl+int',
#        'err', 'succ', 'succ%', 'crdy', 'fls', 'won%', 'season', 'team',
#        'Unnamed: 0', 'venue_code', 'opp_code', 'team_code', 'hour',
#        'day_code', 'form', 'target', 'tts', 'ttc', 'btts', 'above_2.5',
#        'above_3.5'], dtype=object)

# %%
#Predictors for match results
predictors = ["venue_code", "opp_code", "team_code"]
cols_form = ["gf", "ga", "sh", "sot", "dist", "form", "xg", "xga", "poss", "sota", "save%", "cs", "psxg", "cmp", "cmp%", "prgdist",
            "ast", "ppa", "prgp", "sca", "gca", "tklw", "int", "tkl+int", "err", "succ", "succ%", "crdy", "fls", "won%"]
cols_avg = ["gf", "ga", "form", "xg", "xga", "poss", "cs"]
new_cols_form = [f"{c}_rolling_3" for c in cols_form]
new_cols_avg = [f"{c}_rolling_365" for c in cols_avg]

# %%
#Predictors for team to score
predictors = ["venue_code", "opp_code", "team_code"]
cols_form = ["gf", "sh", "sot", "dist", "form", "xg", "poss", "sota", "cmp", "cmp%", "prgdist", "ast", "ppa", 
             "prgp", "sca", "gca", "succ", "succ%", "crdy", "fls", "won%"]
cols_avg = ["gf", "ga", "form", "xg", "xga", "poss", "cs"]
new_cols_form = [f"{c}_rolling_3" for c in cols_form]
new_cols_avg = [f"{c}_rolling_365" for c in cols_avg]

# %%
#Finding rolling average for the team for every 40 matches
#This will be able to show how the team is expected to perform over a long period of time
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols_avg, new_cols_avg, 40))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

#Find rolling averages for the team for every 3 matches
#This will be able to show the recent form of the team in the short term
matches_rolling = matches_rolling.groupby("team").apply(lambda x: rolling_averages(x, cols_form, new_cols_form, 3))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling.to_csv('matches_rolling.csv')
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2018-09-23  16:00  Premier League   Matchweek 6  Sun  Home      W  2.0
# 1    2018-09-29  15:00  Premier League   Matchweek 7  Sat  Home      W  2.0
# 2    2018-10-07  12:00  Premier League   Matchweek 8  Sun  Away      W  5.0
# 3    2018-10-22  20:00  Premier League   Matchweek 9  Mon  Home      W  3.0
# 4    2018-10-28  13:30  Premier League  Matchweek 10  Sun  Away      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 2785 2023-02-04  15:00  Premier League  Matchweek 22  Sat  Home      W  3.0
# 2786 2023-02-11  15:00  Premier League  Matchweek 23  Sat  Away      W  2.0
# 2787 2023-02-18  15:00  Premier League  Matchweek 24  Sat  Home      L  0.0
# 2788 2023-02-24  20:00  Premier League  Matchweek 25  Fri  Away      D  1.0
# 2789 2023-03-01  20:00  Premier League   Matchweek 7  Wed  Away      L  0.0
#
#        ga        opponent  ...  gca_rolling_3  tklw_rolling_3  int_rolling_3  \
# 0     0.0         Everton  ...       4.333333        8.666667       8.000000
# 1     0.0         Watford  ...       4.333333        9.000000       9.000000
# 2     1.0          Fulham  ...       3.000000        7.666667       7.666667
# 3     1.0  Leicester City  ...       5.333333       10.333333      10.000000
# 4     2.0  Crystal Palace  ...       6.000000       10.000000      10.333333
# ...   ...             ...  ...            ...             ...            ...
# 2785  0.0       Liverpool  ...       1.333333       11.333333       7.000000
# 2786  1.0     Southampton  ...       1.666667        9.000000       6.333333
# 2787  1.0     Bournemouth  ...       1.333333       10.000000       7.000000
# 2788  1.0          Fulham  ...       1.333333       11.333333       4.000000
# 2789  2.0       Liverpool  ...       1.000000       13.000000       6.000000
#
#       tkl+int_rolling_3 err_rolling_3 succ_rolling_3 succ%_rolling_3  \
# 0             21.666667      1.000000       7.000000       56.333333
# 1             24.000000      0.666667       6.000000       53.000000
# 2             22.333333      0.333333       6.333333       50.400000
# 3             26.666667      0.666667       7.000000       51.266667
# 4             27.333333      0.666667       9.000000       59.600000
# ...                 ...           ...            ...             ...
# 2785          26.666667      0.666667       5.333333       42.566667
# 2786          21.666667      1.000000       6.000000       47.766667
# 2787          24.333333      1.000000       8.000000       50.800000
# 2788          22.333333      0.666667      12.000000       66.700000
# 2789          25.000000      0.333333      14.333333       67.333333
#
#      crdy_rolling_3  fls_rolling_3  won%_rolling_3
# 0          1.666667      13.666667       49.266667
# 1          2.000000      14.000000       50.766667
# 2          1.333333      13.000000       53.266667
# 3          1.333333      13.333333       50.333333
# 4          1.333333      11.000000       48.333333
# ...             ...            ...             ...
# 2785       1.666667      10.666667       47.966667
# 2786       1.000000       9.666667       43.833333
# 2787       2.333333      11.000000       39.466667
# 2788       2.666667      11.666667       39.933333
# 2789       2.333333      14.333333       46.200000
#
# [2790 rows x 102 columns]

# %% [markdown]
# ## Model Training Using All Variables

# %%
def make_result_predictions(data, predictors, y):
    train = data[data["season"] != 2022]
    test = data[data["season"] == 2022]
    print(f"Splitting data into {round(len(train)/(len(train)+len(test)),2)}:{round(len(test)/(len(train)+len(test)),2)} ratio")
    
    #Random Forest Classifier Model
    rf = RandomForestClassifier(n_estimators=97, criterion='gini', max_depth = 124, min_samples_split = 6,
                                min_samples_leaf = 3, max_features = None, max_leaf_nodes = 1906, 
                                min_impurity_decrease = 0.004238486800121857, bootstrap = True, random_state = 15,
                                oob_score = False, warm_start = True, ccp_alpha = 0.01769784612106034, max_samples = 35)
    
    rf.fit(train[predictors], train[y])
    preds = rf.predict(test[predictors])
    combined_rf = pd.DataFrame(dict(actual=test[y], predicted = preds), index=test.index)
    precision = precision_score(test[y],preds)
    accuracy = accuracy_score(test[y], preds)
    avg = len(test[test[y]==1]) / len(test)
    print("Training Completed for Random Forest")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Average: {avg}")
    
    #Logistic Regression Model
    logreg = LogisticRegression(penalty = 'elasticnet', C = 0.10205138608051409, fit_intercept = False, solver = 'saga',
                               random_state = 22, max_iter = 317, warm_start = True, l1_ratio = 0.04938219562914714)
    logreg.fit(train[predictors], train[y])
    preds = logreg.predict(test[predictors])
    combined_logreg = pd.DataFrame(dict(actual=test[y], predicted = preds), index=test.index)
    precision = precision_score(test[y],preds)
    accuracy = accuracy_score(test[y], preds)
    avg = len(test[test[y]==1]) / len(test)
    print("Training Completed for Logistic Regression")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Average: {avg}")
    
    #XGBClassifier
    xgb = XGBClassifier(booster = 'dart',
                        objective = 'binary:logitraw',
                        sample_type = 'weighted',
                        normalize_type = 'tree',
                        rate_drop = 0.625430139999562,
                        one_drop = 0,
                        skip_drop = 0.5267890691915503)
    xgb.fit(train[predictors], train[y])
    preds = xgb.predict(test[predictors])
    combined_xgb = pd.DataFrame(dict(actual=test[y], predicted = preds), index=test.index)
    precision = precision_score(test[y],preds)
    accuracy = accuracy_score(test[y], preds)
    avg = len(test[test[y]==1]) / len(test)
    print("Training Completed for XGBClassifier")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Average: {avg}")
    
    return combined_rf, combined_logreg, combined_xgb

# %%
#Making predictions on the outcome of the match
combined_rf, combined_logreg, combined_xgb = make_result_predictions(matches_rolling, predictors + new_cols_form + new_cols_avg, "target")
# Out:
# Splitting data into 0.85:0.15 ratio
# Training Completed for Random Forest
# Accuracy: 0.6136865342163356
# Precision: 0.5039370078740157
# Average: 0.38852097130242824
# C:\Users\Lee Seung Soo\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Training Completed for Logistic Regression
# Accuracy: 0.6225165562913907
# Precision: 0.5193798449612403
# Average: 0.38852097130242824
# [19:49:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:1205: Starting in XGBoost 1.4.0, the default evaluation metric used with the objective 'binary:logitraw' was changed from 'auc' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training Completed for XGBClassifier
# Accuracy: 0.609271523178808
# Precision: 0.49586776859504134
# Average: 0.38852097130242824

# %%
#Making predictions on whether both teams will score
combined_rf, combined_logreg, combined_xgb = make_result_predictions(matches_rolling, predictors + new_cols_form + new_cols_avg, "btts")
# Out:
# Splitting data into 0.85:0.15 ratio
# Training Completed for Random Forest
# Accuracy: 0.5165562913907285
# Precision: 0.5076142131979695
# Average: 0.4900662251655629
# C:\Users\Lee Seung Soo\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Training Completed for Logistic Regression
# Accuracy: 0.48344370860927155
# Precision: 0.485
# Average: 0.4900662251655629
# [19:49:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:1205: Starting in XGBoost 1.4.0, the default evaluation metric used with the objective 'binary:logitraw' was changed from 'auc' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training Completed for XGBClassifier
# Accuracy: 0.5695364238410596
# Precision: 0.5838509316770186
# Average: 0.4900662251655629

# %%
#Making predictions on the total goals above 2.5 / 3.5
combined_rf, combined_logreg, combined_xgb = make_result_predictions(matches_rolling, predictors + new_cols_form + new_cols_avg, "above_2.5")
# Out:
# Splitting data into 0.85:0.15 ratio
# Training Completed for Random Forest
# Accuracy: 0.5165562913907285
# Precision: 0.514367816091954
# Average: 0.5055187637969095
# C:\Users\Lee Seung Soo\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Training Completed for Logistic Regression
# Accuracy: 0.5121412803532008
# Precision: 0.5096153846153846
# Average: 0.5055187637969095
# [19:49:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:1205: Starting in XGBoost 1.4.0, the default evaluation metric used with the objective 'binary:logitraw' was changed from 'auc' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training Completed for XGBClassifier
# Accuracy: 0.4922737306843267
# Precision: 0.4978902953586498
# Average: 0.5055187637969095

# %%
combined_rf = combined_rf.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined_logreg = combined_logreg.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined_xgb = combined_xgb.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 pd.crosstab(index=combined["actual"], columns=combined["predicted"])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'predicted'

# %%
combined_rf
# Out:
#       actual  predicted        date                     team        opponent  \
# 141        0          1  2022-08-05                  Arsenal  Crystal Palace
# 142        1          1  2022-08-13                  Arsenal  Leicester City
# 143        1          1  2022-08-20                  Arsenal     Bournemouth
# 144        1          1  2022-08-27                  Arsenal          Fulham
# 145        1          1  2022-08-31                  Arsenal     Aston Villa
# ...      ...        ...         ...                      ...             ...
# 2636       1          1  2022-10-23  Wolverhampton Wanderers  Leicester City
# 2637       0          1  2022-10-29  Wolverhampton Wanderers       Brentford
# 2638       1          1  2022-11-05  Wolverhampton Wanderers        Brighton
# 2639       0          1  2022-11-12  Wolverhampton Wanderers         Arsenal
# 2640       1          1  2022-12-26  Wolverhampton Wanderers         Everton
#
#      result
# 141       W
# 142       W
# 143       W
# 144       W
# 145       W
# ...     ...
# 2636      L
# 2637      D
# 2638      L
# 2639      L
# 2640      W
#
# [267 rows x 6 columns]

# %% [markdown]
# # Model Training Using Selected Variables

# %%
# Making match result predictions using selected variables
selected_predictors = ['team_code','opp_code','venue_code','form_rolling_365','xg_rolling_365','gf_rolling_365',
                       'poss_rolling_365','ga_rolling_365','cs_rolling_365','xga_rolling_365']
combined, precision, accuracy = make_match_result_predictions(matches_rolling, selected_predictors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 4>()
#       1 # Making match result predictions using selected variables
#       2 selected_predictors = ['team_code','opp_code','venue_code','form_rolling_365','xg_rolling_365','gf_rolling_365',
#       3                        'poss_rolling_365','ga_rolling_365','cs_rolling_365','xga_rolling_365']
# ----> 4 combined, precision, accuracy = make_match_result_predictions(matches_rolling, selected_predictors)
#
# NameError: name 'make_match_result_predictions' is not defined

# %%
# Making team to score predictions using selected variables
selected_predictors = ['team_code','opp_code','venue_code','form_rolling_365','xg_rolling_365','gf_rolling_365',
                       'poss_rolling_365','ga_rolling_365','cs_rolling_365','xga_rolling_365']
combined, precision, accuracy = make_btts_result_predictions(matches_rolling, selected_predictors)
# Out:
# Splitting data into 0.88:0.12 ratio
# Training Completed
# Accuracy: 0.6733870967741935
# Precision: 0.7123893805309734

# %%
# Making team to concede predictions using selected variables
selected_predictors = ['team_code','opp_code','venue_code','form_rolling_365','xg_rolling_365','gf_rolling_365',
                       'poss_rolling_365','ga_rolling_365','cs_rolling_365','xga_rolling_365']
combined, precision, accuracy = make_above_result_predictions(matches_rolling, selected_predictors)
# Out:
# Splitting data into 0.88:0.12 ratio
# Training Completed
# Accuracy: 0.7016129032258065
# Precision: 0.38095238095238093

# %%
combined_pred = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0    1
# actual
# 0           6   65
# 1          16  161

# %% [markdown]
# ## Combining Home and Away Predictions

# %%
pd.unique(matches_rolling['team'])
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford',
#        'Brighton and Hove Albion', 'Burnley', 'Chelsea', 'Crystal Palace',
#        'Everton', 'Fulham', 'Huddersfield Town', 'Leeds United',
#        'Leicester City', 'Liverpool', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Norwich City',
#        'Sheffield United', 'Southampton', 'Tottenham Hotspur', 'Watford',
#        'West Bromwich Albion', 'West Ham United',
#        'Wolverhampton Wanderers'], dtype=object)

# %%
pd.unique(matches_rolling['opponent'])
# Out:
# array(['Everton', 'Watford', 'Fulham', 'Leicester City', 'Crystal Palace',
#        'Liverpool', 'Wolves', 'Bournemouth', 'Tottenham',
#        'Manchester Utd', 'Huddersfield', 'West Ham', 'Chelsea',
#        'Cardiff City', 'Manchester City', 'Southampton', 'Newcastle Utd',
#        'Brighton', 'Burnley', 'Aston Villa', 'Sheffield Utd',
#        'Norwich City', 'Leeds United', 'West Brom', 'Brentford',
#        "Nott'ham Forest", 'Arsenal'], dtype=object)

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Leeds United": "Leeds",
    "Leiceister City": "Leiceister",
    "Manchester United": "Manchester Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves",
    "West Bromwich Albion" : "West Brom"
}
mapping = MissingDict(**map_values)

# %%
combined_rf['new_team'] = combined_rf['team'].map(mapping)
combined_rf['new_opponent'] = combined_rf['opponent'].map(mapping)
merged_rf = combined_rf.merge(combined_rf, left_on = ["date", "new_team"], right_on=["date", "new_opponent"])

combined_logreg['new_team'] = combined_logreg['team'].map(mapping)
combined_logreg['new_opponent'] = combined_logreg['opponent'].map(mapping)
merged_logreg = combined_logreg.merge(combined_logreg, left_on = ["date", "new_team"], right_on=["date", "new_opponent"])

combined_xgb['new_team'] = combined_xgb['team'].map(mapping)
combined_xgb['new_opponent'] = combined_xgb['opponent'].map(mapping)
merged_xgb = combined_xgb.merge(combined_xgb, left_on = ["date", "new_team"], right_on=["date", "new_opponent"])

# %%
merged_rf
# Out:
#      actual_x  predicted_x        date                   team_x  \
# 0           1            1  2022-08-05                  Arsenal
# 1           1            1  2022-08-13                  Arsenal
# 2           1            1  2022-08-20                  Arsenal
# 3           1            1  2022-08-27                  Arsenal
# 4           1            1  2022-08-31                  Arsenal
# ..        ...          ...         ...                      ...
# 215         0            0  2022-10-18  Wolverhampton Wanderers
# 216         0            0  2022-10-23  Wolverhampton Wanderers
# 217         0            0  2022-10-29  Wolverhampton Wanderers
# 218         0            0  2022-11-12  Wolverhampton Wanderers
# 219         1            0  2022-12-26  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  new_opponent_x  actual_y  \
# 0    Crystal Palace        W    Arsenal  Crystal Palace         0
# 1    Leicester City        W    Arsenal  Leicester City         0
# 2       Bournemouth        W    Arsenal     Bournemouth         0
# 3            Fulham        W    Arsenal          Fulham         0
# 4       Aston Villa        W    Arsenal     Aston Villa         0
# ..              ...      ...        ...             ...       ...
# 215  Crystal Palace        L     Wolves  Crystal Palace         1
# 216  Leicester City        L     Wolves  Leicester City         1
# 217       Brentford        D     Wolves       Brentford         0
# 218         Arsenal        L     Wolves         Arsenal         1
# 219         Everton        W     Wolves         Everton         0
#
#      predicted_y          team_y opponent_y result_y      new_team_y  \
# 0              0  Crystal Palace    Arsenal        L  Crystal Palace
# 1              0  Leicester City    Arsenal        L  Leicester City
# 2              0     Bournemouth    Arsenal        L     Bournemouth
# 3              0          Fulham    Arsenal        L          Fulham
# 4              0     Aston Villa    Arsenal        L     Aston Villa
# ..           ...             ...        ...      ...             ...
# 215            0  Crystal Palace     Wolves        W  Crystal Palace
# 216            0  Leicester City     Wolves        W  Leicester City
# 217            0       Brentford     Wolves        D       Brentford
# 218            1         Arsenal     Wolves        W         Arsenal
# 219            0         Everton     Wolves        L         Everton
#
#     new_opponent_y
# 0          Arsenal
# 1          Arsenal
# 2          Arsenal
# 3          Arsenal
# 4          Arsenal
# ..             ...
# 215         Wolves
# 216         Wolves
# 217         Wolves
# 218         Wolves
# 219         Wolves
#
# [220 rows x 15 columns]

# %% [markdown]
# ### For Win-Lose Result Prediction

# %%
print("Random Forest Classifier")
win_count = merged_rf[(merged_rf["predicted_x"] == 1) & (merged_rf["predicted_y"] == 0)]
precision_win = len(win_count[win_count['actual_x'] == 1]) / len(win_count)
print(f"Team wins when model predicts that team will win and opponent will lose: {round(precision_win, 5)}")

draw_count = merged_rf[(merged_rf["predicted_x"] == 0) & (merged_rf["predicted_y"] == 0)]
precision_draw = len(draw_count[draw_count['result_x'] == 'D']) / len(draw_count)
print(f"Team draws when model predicts that both teams will lose or win: {round(precision_draw, 5)}")
print("")

print("Logistic Regression")
win_count = merged_logreg[(merged_logreg["predicted_x"] == 1) & (merged_logreg["predicted_y"] == 0)]
precision_win = len(win_count[win_count['actual_x'] == 1]) / len(win_count)
print(f"Team wins when model predicts that team will win and opponent will lose: {round(precision_win, 5)}")

draw_count = merged_logreg[(merged_logreg["predicted_x"] == 0) & (merged_logreg["predicted_y"] == 0)]
precision_draw = len(draw_count[draw_count['result_x'] == 'D']) / len(draw_count)
print(f"Team draws when model predicts that both teams will lose or win: {round(precision_draw, 5)}")
print("")

print("XGBoost Classifier")
win_count = merged_xgb[(merged_xgb["predicted_x"] == 1) & (merged_xgb["predicted_y"] == 0)]
precision_win = len(win_count[win_count['actual_x'] == 1]) / len(win_count)
print(f"Team wins when model predicts that team will win and opponent will lose: {round(precision_win, 5)}")

draw_count = merged_xgb[(merged_xgb["predicted_x"] == 0) & (merged_xgb["predicted_y"] == 0)]
precision_draw = len(draw_count[draw_count['result_x'] == 'D']) / len(draw_count)
print(f"Team draws when model predicts that both teams will lose or win: {round(precision_draw, 5)}")
print("")
# Out:
# Random Forest Classifier
# Team wins when model predicts that team will win and opponent will lose: 0.67347
# Team draws when model predicts that both teams will lose or win: 0.23478
#
# Logistic Regression
# Team wins when model predicts that team will win and opponent will lose: 0.62162
# Team draws when model predicts that both teams will lose or win: 0.21168
#
# XGBoost Classifier
# Team wins when model predicts that team will win and opponent will lose: 0.55319
# Team draws when model predicts that both teams will lose or win: 0.19492

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]
# Out:
#      actual_x  predicted_x       date             team_x      opponent_x  \
# 0           1            1 2022-08-05            Arsenal  Crystal Palace
# 4           1            1 2022-08-31            Arsenal     Aston Villa
# 6           1            1 2022-09-18            Arsenal       Brentford
# 10          0            1 2022-10-23            Arsenal     Southampton
# 11          1            1 2022-11-06            Arsenal         Chelsea
# 12          1            1 2022-11-12            Arsenal          Wolves
# 19          1            1 2022-09-16        Aston Villa     Southampton
# 53          0            1 2022-08-21            Chelsea    Leeds United
# 54          1            1 2022-08-27            Chelsea  Leicester City
# 55          0            1 2022-08-30            Chelsea     Southampton
# 56          1            1 2022-09-03            Chelsea        West Ham
# 57          1            1 2022-10-01            Chelsea  Crystal Palace
# 58          1            1 2022-10-08            Chelsea          Wolves
# 59          1            1 2022-10-16            Chelsea     Aston Villa
# 60          0            1 2022-10-22            Chelsea  Manchester Utd
# 121         1            1 2022-10-20     Leicester City    Leeds United
# 124         1            1 2022-11-12     Leicester City        West Ham
# 125         0            1 2022-08-06          Liverpool          Fulham
# 126         0            1 2022-08-15          Liverpool  Crystal Palace
# 128         1            1 2022-08-27          Liverpool     Bournemouth
# 129         1            1 2022-08-31          Liverpool   Newcastle Utd
# 130         0            1 2022-09-03          Liverpool         Everton
# 131         0            1 2022-10-01          Liverpool        Brighton
# 132         0            1 2022-10-09          Liverpool         Arsenal
# 133         1            1 2022-10-19          Liverpool        West Ham
# 134         0            1 2022-10-29          Liverpool    Leeds United
# 136         1            1 2022-11-12          Liverpool     Southampton
# 137         1            1 2022-08-07    Manchester City        West Ham
# 138         1            1 2022-08-13    Manchester City     Bournemouth
# 139         1            1 2022-08-27    Manchester City  Crystal Palace
# 140         0            1 2022-09-03    Manchester City     Aston Villa
# 141         1            1 2022-09-17    Manchester City          Wolves
# 142         1            1 2022-10-02    Manchester City  Manchester Utd
# 143         1            1 2022-10-08    Manchester City     Southampton
# 144         1            1 2022-11-05    Manchester City          Fulham
# 145         0            1 2022-11-12    Manchester City       Brentford
# 171         0            1 2022-08-31  Tottenham Hotspur        West Ham
# 172         1            1 2022-09-03  Tottenham Hotspur          Fulham
# 173         1            1 2022-09-17  Tottenham Hotspur  Leicester City
# 175         1            1 2022-10-08  Tottenham Hotspur        Brighton
# 176         1            1 2022-10-15  Tottenham Hotspur         Everton
# 178         1            1 2022-11-12  Tottenham Hotspur    Leeds United
# 180         0            1 2022-08-21    West Ham United        Brighton
# 181         1            1 2022-08-28    West Ham United     Aston Villa
# 187         0            1 2022-10-16    West Ham United     Southampton
#
#     result_x       new_team_x  new_opponent_x  actual_y  predicted_y  \
# 0          W          Arsenal  Crystal Palace         0            0
# 4          W          Arsenal     Aston Villa         0            0
# 6          W          Arsenal       Brentford         0            0
# 10         D          Arsenal     Southampton         0            0
# 11         W          Arsenal         Chelsea         0            0
# 12         W          Arsenal          Wolves         0            0
# 19         W      Aston Villa     Southampton         0            0
# 53         L          Chelsea           Leeds         1            0
# 54         W          Chelsea  Leicester City         0            0
# 55         L          Chelsea     Southampton         1            0
# 56         W          Chelsea        West Ham         0            0
# 57         W          Chelsea  Crystal Palace         0            0
# 58         W          Chelsea          Wolves         0            0
# 59         W          Chelsea     Aston Villa         0            0
# 60         D          Chelsea  Manchester Utd         0            0
# 121        W   Leicester City           Leeds         0            0
# 124        W   Leicester City        West Ham         0            0
# 125        D        Liverpool          Fulham         0            0
# 126        D        Liverpool  Crystal Palace         0            0
# 128        W        Liverpool     Bournemouth         0            0
# 129        W        Liverpool   Newcastle Utd         0            0
# 130        D        Liverpool         Everton         0            0
# 131        D        Liverpool        Brighton         0            0
# 132        L        Liverpool         Arsenal         1            0
# 133        W        Liverpool        West Ham         0            0
# 134        L        Liverpool           Leeds         1            0
# 136        W        Liverpool     Southampton         0            0
# 137        W  Manchester City        West Ham         0            0
# 138        W  Manchester City     Bournemouth         0            0
# 139        W  Manchester City  Crystal Palace         0            0
# 140        D  Manchester City     Aston Villa         0            0
# 141        W  Manchester City          Wolves         0            0
# 142        W  Manchester City  Manchester Utd         0            0
# 143        W  Manchester City     Southampton         0            0
# 144        W  Manchester City          Fulham         0            0
# 145        L  Manchester City       Brentford         1            0
# 171        D        Tottenham        West Ham         0            0
# 172        W        Tottenham          Fulham         0            0
# 173        W        Tottenham  Leicester City         0            0
# 175        W        Tottenham        Brighton         0            0
# 176        W        Tottenham         Everton         0            0
# 178        W        Tottenham           Leeds         0            0
# 180        L         West Ham        Brighton         1            0
# 181        W         West Ham     Aston Villa         0            0
# 187        D         West Ham     Southampton         0            0
#
#                        team_y       opponent_y result_y        new_team_y  \
# 0              Crystal Palace          Arsenal        L    Crystal Palace
# 4                 Aston Villa          Arsenal        L       Aston Villa
# 6                   Brentford          Arsenal        L         Brentford
# 10                Southampton          Arsenal        D       Southampton
# 11                    Chelsea          Arsenal        L           Chelsea
# 12    Wolverhampton Wanderers          Arsenal        L            Wolves
# 19                Southampton      Aston Villa        L       Southampton
# 53               Leeds United          Chelsea        W             Leeds
# 54             Leicester City          Chelsea        L    Leicester City
# 55                Southampton          Chelsea        W       Southampton
# 56            West Ham United          Chelsea        L          West Ham
# 57             Crystal Palace          Chelsea        L    Crystal Palace
# 58    Wolverhampton Wanderers          Chelsea        L            Wolves
# 59                Aston Villa          Chelsea        L       Aston Villa
# 60          Manchester United          Chelsea        D    Manchester Utd
# 121              Leeds United   Leicester City        L             Leeds
# 124           West Ham United   Leicester City        L          West Ham
# 125                    Fulham        Liverpool        D            Fulham
# 126            Crystal Palace        Liverpool        D    Crystal Palace
# 128               Bournemouth        Liverpool        L       Bournemouth
# 129          Newcastle United        Liverpool        L  Newcastle United
# 130                   Everton        Liverpool        D           Everton
# 131  Brighton and Hove Albion        Liverpool        D          Brighton
# 132                   Arsenal        Liverpool        W           Arsenal
# 133           West Ham United        Liverpool        L          West Ham
# 134              Leeds United        Liverpool        W             Leeds
# 136               Southampton        Liverpool        L       Southampton
# 137           West Ham United  Manchester City        L          West Ham
# 138               Bournemouth  Manchester City        L       Bournemouth
# 139            Crystal Palace  Manchester City        L    Crystal Palace
# 140               Aston Villa  Manchester City        D       Aston Villa
# 141   Wolverhampton Wanderers  Manchester City        L            Wolves
# 142         Manchester United  Manchester City        L    Manchester Utd
# 143               Southampton  Manchester City        L       Southampton
# 144                    Fulham  Manchester City        L            Fulham
# 145                 Brentford  Manchester City        W         Brentford
# 171           West Ham United        Tottenham        D          West Ham
# 172                    Fulham        Tottenham        L            Fulham
# 173            Leicester City        Tottenham        L    Leicester City
# 175  Brighton and Hove Albion        Tottenham        L          Brighton
# 176                   Everton        Tottenham        L           Everton
# 178              Leeds United        Tottenham        L             Leeds
# 180  Brighton and Hove Albion         West Ham        W          Brighton
# 181               Aston Villa         West Ham        L       Aston Villa
# 187               Southampton         West Ham        D       Southampton
#
#       new_opponent_y
# 0            Arsenal
# 4            Arsenal
# 6            Arsenal
# 10           Arsenal
# 11           Arsenal
# 12           Arsenal
# 19       Aston Villa
# 53           Chelsea
# 54           Chelsea
# 55           Chelsea
# 56           Chelsea
# 57           Chelsea
# 58           Chelsea
# 59           Chelsea
# 60           Chelsea
# 121   Leicester City
# 124   Leicester City
# 125        Liverpool
# 126        Liverpool
# 128        Liverpool
# 129        Liverpool
# 130        Liverpool
# 131        Liverpool
# 132        Liverpool
# 133        Liverpool
# 134        Liverpool
# 136        Liverpool
# 137  Manchester City
# 138  Manchester City
# 139  Manchester City
# 140  Manchester City
# 141  Manchester City
# 142  Manchester City
# 143  Manchester City
# 144  Manchester City
# 145  Manchester City
# 171        Tottenham
# 172        Tottenham
# 173        Tottenham
# 175        Tottenham
# 176        Tottenham
# 178        Tottenham
# 180         West Ham
# 181         West Ham
# 187         West Ham

# %%
merged[(merged["predicted_x"] == 0) & (merged["predicted_y"] == 0)]
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 1           1            0 2022-08-13                  Arsenal
# 2           1            0 2022-08-20                  Arsenal
# 3           1            0 2022-08-27                  Arsenal
# 5           0            0 2022-09-04                  Arsenal
# 9           1            0 2022-10-16                  Arsenal
# ..        ...          ...        ...                      ...
# 196         1            0 2022-09-03  Wolverhampton Wanderers
# 198         0            0 2022-10-01  Wolverhampton Wanderers
# 200         0            0 2022-10-18  Wolverhampton Wanderers
# 201         0            0 2022-10-23  Wolverhampton Wanderers
# 202         0            0 2022-10-29  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  new_opponent_x  actual_y  \
# 1    Leicester City        W    Arsenal  Leicester City         0
# 2       Bournemouth        W    Arsenal     Bournemouth         0
# 3            Fulham        W    Arsenal          Fulham         0
# 5    Manchester Utd        L    Arsenal  Manchester Utd         1
# 9      Leeds United        W    Arsenal           Leeds         0
# ..              ...      ...        ...             ...       ...
# 196     Southampton        W     Wolves     Southampton         0
# 198        West Ham        L     Wolves        West Ham         1
# 200  Crystal Palace        L     Wolves  Crystal Palace         1
# 201  Leicester City        L     Wolves  Leicester City         1
# 202       Brentford        D     Wolves       Brentford         0
#
#      predicted_y             team_y opponent_y result_y      new_team_y  \
# 1              0     Leicester City    Arsenal        L  Leicester City
# 2              0        Bournemouth    Arsenal        L     Bournemouth
# 3              0             Fulham    Arsenal        L          Fulham
# 5              0  Manchester United    Arsenal        W  Manchester Utd
# 9              0       Leeds United    Arsenal        L           Leeds
# ..           ...                ...        ...      ...             ...
# 196            0        Southampton     Wolves        L     Southampton
# 198            0    West Ham United     Wolves        W        West Ham
# 200            0     Crystal Palace     Wolves        W  Crystal Palace
# 201            0     Leicester City     Wolves        W  Leicester City
# 202            0          Brentford     Wolves        D       Brentford
#
#     new_opponent_y
# 1          Arsenal
# 2          Arsenal
# 3          Arsenal
# 5          Arsenal
# 9          Arsenal
# ..             ...
# 196         Wolves
# 198         Wolves
# 200         Wolves
# 201         Wolves
# 202         Wolves
#
# [109 rows x 15 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 1)]
# Out:
#      actual_x  predicted_x       date             team_x      opponent_x  \
# 7           1            1 2022-10-01            Arsenal       Tottenham
# 127         0            1 2022-08-22          Liverpool  Manchester Utd
# 135         1            1 2022-11-06          Liverpool       Tottenham
# 147         1            1 2022-08-22  Manchester United       Liverpool
# 174         0            1 2022-10-01  Tottenham Hotspur         Arsenal
# 177         0            1 2022-11-06  Tottenham Hotspur       Liverpool
#
#     result_x      new_team_x  new_opponent_x  actual_y  predicted_y  \
# 7          W         Arsenal       Tottenham         0            1
# 127        L       Liverpool  Manchester Utd         1            1
# 135        W       Liverpool       Tottenham         0            1
# 147        W  Manchester Utd       Liverpool         0            1
# 174        L       Tottenham         Arsenal         1            1
# 177        L       Tottenham       Liverpool         1            1
#
#                 team_y      opponent_y result_y      new_team_y  \
# 7    Tottenham Hotspur         Arsenal        L       Tottenham
# 127  Manchester United       Liverpool        W  Manchester Utd
# 135  Tottenham Hotspur       Liverpool        L       Tottenham
# 147          Liverpool  Manchester Utd        L       Liverpool
# 174            Arsenal       Tottenham        W         Arsenal
# 177          Liverpool       Tottenham        W       Liverpool
#
#      new_opponent_y
# 7           Arsenal
# 127       Liverpool
# 135       Liverpool
# 147  Manchester Utd
# 174       Tottenham
# 177       Tottenham

# %% [markdown]
# ### For Both Teams To Score Prediction

# %%
print("Random Forest Classifier")
btts_count = merged_rf[(merged_rf["predicted_x"] == 1) & (merged_rf["predicted_y"] == 1)]
precision_btts = len(btts_count[(btts_count['actual_x'] == 1) & (btts_count['actual_y'] == 1)]) / len(btts_count)
print(f"Both teams actually score when model predicts that both teams score: {round(precision_btts, 5)}")
print("")

print("Logistic Regression")
btts_count = merged_logreg[(merged_logreg["predicted_x"] == 1) & (merged_logreg["predicted_y"] == 1)]
precision_btts = len(btts_count[(btts_count['actual_x'] == 1) & (btts_count['actual_y'] == 1)]) / len(btts_count)
print(f"Both teams actually score when model predicts that both teams score: {round(precision_btts, 5)}")
print("")

print("XGB Classifier")
btts_count = merged_xgb[(merged_xgb["predicted_x"] == 1) & (merged_xgb["predicted_y"] == 1)]
precision_btts = len(btts_count[(btts_count['actual_x'] == 1) & (btts_count['actual_y'] == 1)]) / len(btts_count)
print(f"Both teams actually score when model predicts that both teams score: {round(precision_btts, 5)}")
print("")
# Out:
# Random Forest Classifier
# Both teams actually score when model predicts that both teams score: 0.86207
#
# Logistic Regression
# Both teams actually score when model predicts that both teams score: 0.63636
#
# XGB Classifier
# Both teams actually score when model predicts that both teams score: 0.63934

# %%
btts_count = merged_rf[((merged_rf["predicted_x"] == 1) & (merged_rf["predicted_y"] == 0)) | 
                      ((merged_rf["predicted_x"] == 0) & (merged_rf["predicted_y"] == 1))]
precision_btts = len(btts_count[(btts_count['actual_x'] == 1) & (btts_count['actual_y'] == 1)]) / len(btts_count)
print(f"Both teams actually score when model predicts that both teams score: {round(precision_btts, 5)}")
print("")
# Out:
# Both teams actually score when model predicts that both teams score: 0.55372

# %% [markdown]
# ### For Above 2.5/3.5 Prediction

# %%
print("Random Forest Classifier")
above_count = merged_rf[(merged_rf["predicted_x"] == 1) & (merged_rf["predicted_y"] == 1)]
precision_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)
print(f"Total goals above 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")

below_count = merged_rf[(merged_rf["predicted_x"] == 0) & (merged_rf["predicted_y"] == 0)]
precision_above = len(below_count[below_count["actual_x"] == 0]) / len(below_count)
print(f"Total goals below 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")

print("Logistic Regression")
above_count = merged_logreg[(merged_logreg["predicted_x"] == 1) & (merged_logreg["predicted_y"] == 1)]
precision_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)
print(f"Total goals above 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")

below_count = merged_logreg[(merged_logreg["predicted_x"] == 0) & (merged_logreg["predicted_y"] == 0)]
precision_above = len(below_count[below_count["actual_x"] == 0]) / len(below_count)
print(f"Total goals below 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")

print("XGBoost Classifier")
above_count = merged_xgb[(merged_xgb["predicted_x"] == 1) & (merged_xgb["predicted_y"] == 1)]
precision_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)
print(f"Total goals above 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")

below_count = merged_xgb[(merged_xgb["predicted_x"] == 0) & (merged_xgb["predicted_y"] == 0)]
precision_above = len(below_count[below_count["actual_x"] == 0]) / len(below_count)
print(f"Total goals below 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")
# Out:
# Random Forest Classifier
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#       1 print("Random Forest Classifier")
# ----> 2 above_count = merged_rf[(merged_rf["predicted_x"] == 1) & (merged_rf["predicted_y"] == 1)]
#       3 precision_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)
#       4 print(f"Total goals above 2.5/3.5 when model predicts as such: {round(precision_above, 5)}")
#
# NameError: name 'merged_rf' is not defined

# %% [markdown]
# # Predicting Today's Game

# %%
side1 = 'Manchester City'
side2 = 'Leeds'

# %% [markdown]
# ## Predicting Side 1

# %%
#Printing out the result
side1_pred = combined[(combined['new_team'] == side1) & (combined['new_opponent'] == side2)]
for index, row in side1_pred.iterrows():
    if row['predicted'] == 1:
        print(f"{side1} Wins!")
        break
    else:
        print(f"{side1} Loses!")
        break
# Out:
# Manchester City Wins!

# %% [markdown]
# ## Predicting Side 2

# %%
#Printing out the result
side2_pred = combined[(combined['new_team'] == side2) & (combined['new_opponent'] == side1)]
for index, row in side2_pred.iterrows():
    if row['predicted'] == 1:
        print(f"{side2} Wins!")
        break
    else:
        print(f"{side2} Loses!")
        break
# Out:
# Leeds Loses!

# %%
#Predictors for match results
predictors = ["venue_code", "opp_code", "team_code"]
cols_form = ["gf", "ga", "sh", "sot", "dist", "form", "xg", "poss", "sota", "save%", "cs", "psxg", "cmp", "cmp%", "prgdist",
            "ast", "ppa", "prog", "sca", "gca", "tklw", "int", "tkl+int", "err", "succ", "succ%", "crdy", "fls", "won%"]
cols_avg = ["gf", "ga", "form", "xg", "xga", "poss", "cs"]
new_cols_form = [f"{c}_rolling_3" for c in cols_form]
new_cols_avg = [f"{c}_rolling_365" for c in cols_avg]

# %%
#Predictors for team to score
predictors = ["venue_code", "opp_code", "team_code"]
cols_form = ["gf", "sh", "sot", "dist", "form", "xg", "poss", "sota", "cmp", "cmp%", "prgdist", "ast", "ppa", 
             "prog", "sca", "gca", "succ", "succ%", "crdy", "fls", "won%"]
cols_avg = ["gf", "ga", "form", "xg", "xga", "poss", "cs"]
new_cols_form = [f"{c}_rolling_3" for c in cols_form]
new_cols_avg = [f"{c}_rolling_365" for c in cols_avg]

# %%
train = matches_rolling[matches_rolling["season"] != 2022]
test = matches_rolling[matches_rolling["season"] == 2022]
predictors = predictors + new_cols_form + new_cols_avg

xgb = XGBClassifier(booster = 'gbtree',
                   objective = 'binary:logitraw',
                   eta = 0.7728938824808032,
                   gamma = 2.4465720216663955,
                   max_depth = 13,
                   min_child_weight = 2.6132315739082834,
                   max_delta_step = 3,
                   subsample = 0.41452825994375864,
                   reg_lambda = 2.5427342332070166,
                   reg_alpha = 1.97083175662957,
                   tree_method = 'hist',
                   grow_policy = 'depthwise',
                   max_leaves = 6,
                   max_bin = 423)
xgb.fit(train[predictors], train['above_2.5'])

test_preds = xgb.predict(test[predictors])
test_combined = pd.DataFrame(dict(actual=test['above_2.5'], predicted = test_preds), index=test.index)
test_combined = test_combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
test_combined['new_team'] = test_combined['team'].map(mapping)
test_combined['new_opponent'] = test_combined['opponent'].map(mapping)
test_merged = test_combined.merge(test_combined, left_on = ["date", "new_team"], right_on=["date", "new_opponent"])

train_preds = xgb.predict(train[predictors])
train_combined = pd.DataFrame(dict(actual=train['above_2.5'], predicted = train_preds), index=train.index)
train_combined = train_combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
train_combined['new_team'] = train_combined['team'].map(mapping)
train_combined['new_opponent'] = train_combined['opponent'].map(mapping)
train_merged = train_combined.merge(train_combined, left_on = ["date", "new_team"], right_on=["date", "new_opponent"])

above_count = train_merged[(train_merged["predicted_x"] == 1) & (train_merged["predicted_y"] == 1)]
precision_train_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)

above_count = test_merged[(test_merged["predicted_x"] == 1) & (test_merged["predicted_y"] == 1)]
precision_test_above = len(above_count[above_count["actual_x"] == 1]) / len(above_count)

print(f"Train: {precision_train_above}")
print(f"Test: {precision_test_above}")
print(f"Avg1: {(precision_train_above + precision_test_above) / 2}")
print(f"Avg2: {0.8739837398373984}")
# Out:
# [21:19:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:1205: Starting in XGBoost 1.4.0, the default evaluation metric used with the objective 'binary:logitraw' was changed from 'auc' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Train: 0.9600886917960089
# Test: 0.7878787878787878
# Avg1: 0.8739837398373984
# Avg2: 0.8739837398373984
